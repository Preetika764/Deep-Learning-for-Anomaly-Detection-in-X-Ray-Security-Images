# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# %%
import os
print(os.getcwd())
os.path.join(os.getcwd(),'10/train.csv')
# Out:
# /content
# '/content/10/train.csv'

# %%
import pandas as pd
train = pd.read_csv(os.path.join(os.getcwd(),'10/train.csv'))
train
# Out:
#            name  Gun  Knife  Wrench  Pliers  Scissors
# 0        P03198    1     -1       1      -1        -1
# 1        P02604    1     -1      -1      -1        -1
# 2        P02457    1     -1      -1      -1        -1
# 3        P03561    1      1       1       1        -1
# 4        P00087    1      1      -1      -1        -1
# ...         ...  ...    ...     ...     ...       ...
# 74955  N0659455   -1     -1      -1      -1        -1
# 74956  N0189692   -1     -1      -1      -1        -1
# 74957  N0183634   -1     -1      -1      -1        -1
# 74958  N0702335   -1     -1      -1      -1        -1
# 74959  N0756785   -1     -1      -1      -1        -1
#
# [74960 rows x 6 columns]

# %%
import pandas as pd
test = pd.read_csv(os.path.join(os.getcwd(),'10/test.csv'))
test
# Out:
#            name  Gun  Knife  Wrench  Pliers  Scissors
# 0        P00007   -1      1      -1      -1        -1
# 1        P00010   -1      1      -1      -1        -1
# 2        P00022   -1      1      -1      -1        -1
# 3        P00024   -1      1      -1      -1        -1
# 4        P00028   -1      1      -1      -1        -1
# ...         ...  ...    ...     ...     ...       ...
# 13407  N0167173   -1     -1      -1      -1        -1
# 13408  N0587613   -1     -1      -1      -1        -1
# 13409  N0676892   -1     -1      -1      -1        -1
# 13410  N0794177   -1     -1      -1      -1        -1
# 13411  N0420479   -1     -1      -1      -1        -1
#
# [13412 rows x 6 columns]

# %%
import shutil
import os
i = 0
testP = []

for row in test.iterrows():
  if os.path.exists(os.getcwd() + '/P/' + str(row[1][0]) + '.jpg') :
    sourcecopy = os.getcwd() + '/P/' + str(row[1][0]) + '.jpg'
    destinationcopy = os.getcwd() + '/test/' + str(row[1][0]) + '.jpg'
    shutil.copy(sourcecopy,destinationcopy)
    testP.append(str(row[1][0]))
      
print(testP)
print(len(testP))
# Out:
# ['P00007', 'P00010', 'P00022', 'P00024', 'P00028', 'P00066', 'P00073', 'P00078', 'P00120', 'P00124', 'P00151', 'P00161', 'P00174', 'P00178', 'P00209', 'P00213', 'P00225', 'P00234', 'P00246', 'P00248', 'P00264', 'P00276', 'P00278', 'P00289', 'P00306', 'P00309', 'P00311', 'P00317', 'P00325', 'P00328', 'P00343', 'P00420', 'P00445', 'P00467', 'P00473', 'P00514', 'P00523', 'P00544', 'P00572', 'P00588', 'P00590', 'P00592', 'P00598', 'P00618', 'P00620', 'P00622', 'P00626', 'P00628', 'P00630', 'P00633', 'P00639', 'P00641', 'P00643', 'P00645', 'P00651', 'P00654', 'P00655', 'P00673', 'P00686', 'P00721', 'P00723', 'P00729', 'P00731', 'P00739', 'P00741', 'P00744', 'P00745', 'P00763', 'P00800', 'P00886', 'P00887', 'P00911', 'P00915', 'P00916', 'P00922', 'P00961', 'P00994', 'P01016', 'P01045', 'P01047', 'P01062', 'P01064', 'P01065', 'P01071', 'P01072', 'P01118', 'P01130', 'P01181', 'P01182', 'P01207', 'P01208', 'P01209', 'P01215', 'P01220', 'P01224', 'P01229', 'P01234', 'P01239', 'P01240', 'P01246
# ...

# %%
import shutil
import os
i = 0
trainP = []

for row in train.iterrows():
  if os.path.exists(os.getcwd() + '/P/' + str(row[1][0]) + '.jpg') :
    sourcecopy = os.getcwd() + '/P/' + str(row[1][0]) + '.jpg'
    destinationcopy = os.getcwd() + '/train/' + str(row[1][0]) + '.jpg'
    shutil.copy(sourcecopy,destinationcopy)
    trainP.append(str(row[1][0]))
      
print(trainP)
print(len(trainP))
# Out:
# ['P03198', 'P02604', 'P02457', 'P03561', 'P00087', 'P02998', 'P01999', 'P02700', 'P02441', 'P00793', 'P02614', 'P00591', 'P03190', 'P01900', 'P02753', 'P01468', 'P02709', 'P03683', 'P00157', 'P03072', 'P03154', 'P00316', 'P03138', 'P02444', 'P00030', 'P01411', 'P02643', 'P03130', 'P00724', 'P03085', 'P02895', 'P02276', 'P00116', 'P00184', 'P01628', 'P01023', 'P01781', 'P01879', 'P02110', 'P01715', 'P00018', 'P00929', 'P00411', 'P01647', 'P02187', 'P01481', 'P02657', 'P00779', 'P02122', 'P02493', 'P02600', 'P00968', 'P00212', 'P01894', 'P01505', 'P00965', 'P01969', 'P02573', 'P02246', 'P01292', 'P03004', 'P02199', 'P00362', 'P03013', 'P01565', 'P01154', 'P02522', 'P01425', 'P01824', 'P03637', 'P03658', 'P03116', 'P00059', 'P01629', 'P02169', 'P03522', 'P01365', 'P03123', 'P03208', 'P02402', 'P03611', 'P02361', 'P02103', 'P01252', 'P03074', 'P01558', 'P02212', 'P01651', 'P03028', 'P03093', 'P01226', 'P01874', 'P01946', 'P02223', 'P01272', 'P02322', 'P01777', 'P00235', 'P00858', 'P00305
# ...

# %%
import shutil
import os
testN = []
trainN = []
i = 1
source = os.getcwd() + '/N-8929/'
destination1 = os.getcwd() + '/train/'
destination2 = os.getcwd() + '/test/'
for files in os.listdir(source):
  source1 = os.path.join(source,files)
  print(source1)
  if i<=1433:
    destinationcopy = os.path.join(destination2,files)
    shutil.copy(source1,destinationcopy)
    testN.append(files)
  else:
    destinationcopy = os.path.join(destination1,files)
    shutil.copy(source1,destinationcopy)
    trainN.append(files)
  i+=1
print(len(trainN))
print(len(testN))
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005648.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005901.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005896.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005690.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005708.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005921.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005632.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005933.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005667.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005938.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005854.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005619.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005861.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005718.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005628.jpg
# /content/gdrive/My Drive/PS1/Dataset/N-8929/N0005919.jpg
# ...

# %%
import json
def write_json(new_data, filename='test.json'):
    with open(filename,'r+') as file:
          # First we load existing data into a dict.
        file_data = json.load(file)
        # Join new_data with file_data inside emp_details
        file_data["samples"].append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file, indent = 4)

# %%
for i in range(len(testN)):
      image_name = testN[i]
      image_labels = []
      a_dict={}
  
      for variable in ["image_name", "image_labels"]:
        a_dict[variable] = eval(variable)
      #print(json.dumps(a_dict)) 
      write_json(a_dict)

# %%
def write_json(new_data, filename='test.json'):
    with open(filename,'r+') as file:
          # First we load existing data into a dict.
        file_data = json.load(file)
        # Join new_data with file_data inside emp_details
        file_data["samples"].append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file, indent = 4)

# %%
import os
import json
i = 0
b_dict = {}

test.reset_index().to_json(orient='records')
for row in test.iterrows():
  if os.path.exists(os.getcwd() + '/P/' + str(row[1][0]) + '.jpg') :
      image_name = str(row[1][0])+'.jpg'
      image_labels = []
      if(row[1][1]==1):
        image_labels.append("Gun")
      if(row[1][2]==1):
        image_labels.append("Knife")
      if(row[1][3]==1):
        image_labels.append("Wrench")
      if(row[1][4]==1):
        image_labels.append("Pliers")
      if(row[1][5]==1):
        image_labels.append("Scissors")
      #print(image_labels)
      a_dict={}
  
      for variable in ["image_name", "image_labels"]:
        a_dict[variable] = eval(variable)
      #print(json.dumps(a_dict)) 
      write_json(a_dict)
      i+=1

# %%
def write_json(new_data, filename='train.json'):
    with open(filename,'r+') as file:
          # First we load existing data into a dict.
        file_data = json.load(file)
        # Join new_data with file_data inside emp_details
        file_data["samples"].append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file, indent = 4)

# %%
for i in range(len(trainN)):
      image_name = trainN[i]
      image_labels = []
      a_dict={}
  
      for variable in ["image_name", "image_labels"]:
        a_dict[variable] = eval(variable)
      #print(json.dumps(a_dict)) 
      write_json(a_dict)

# %%
def write_json(new_data, filename='train.json'):
    with open(filename,'r+') as file:
          # First we load existing data into a dict.
        file_data = json.load(file)
        # Join new_data with file_data inside emp_details
        file_data["samples"].append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file, indent = 4)

# %%
import os
import json
i = 0
b_dict = {}

for row in train.iterrows():
  if os.path.exists(os.getcwd() + '/P/' + str(row[1][0]) + '.jpg') :
      image_name = str(row[1][0])+'.jpg'
      image_labels = []
      if(row[1][1]==1):
        image_labels.append("Gun")
      if(row[1][2]==1):
        image_labels.append("Knife")
      if(row[1][3]==1):
        image_labels.append("Wrench")
      if(row[1][4]==1):
        image_labels.append("Pliers")
      if(row[1][5]==1):
        image_labels.append("Scissors")
      #print(image_labels)
      a_dict={}
  
      for variable in ["image_name", "image_labels"]:
        a_dict[variable] = eval(variable)
      #print(json.dumps(a_dict)) 
      write_json(a_dict)
      i+=1
